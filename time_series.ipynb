# %% [markdown]
# <a href="https://colab.research.google.com/github/Belal-AI/Rev-Projects/blob/main/time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import IPython.display as ipd

# %%
fname = '/content/002d392d.wav'  # Hi-hat
ipd.Audio(fname)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from glob import  glob
import librosa as lr
import numpy as np
import matplotlib.pyplot as plt

# %%
files=glob("/content/waves"+'/*.wav')

# %%
files
# Out:
# ['/content/waves/0013a1db.wav',
#  '/content/waves/002d392d.wav',
#  '/content/waves/002bb878.wav',
#  '/content/waves/00063640.wav']

# %%
audio,sfrq=lr.load(files[0])

# %%
indxis=np.arange(0,len(audio))

# %%
stamps=indxis/sfrq

# %%
plt.plot(stamps,audio)
