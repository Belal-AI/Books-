# %% [markdown]
# <a href="https://colab.research.google.com/github/Belal-AI/Rev-Projects/blob/main/anomlydetections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import KernelDensity
import matplotlib.pyplot as plt
from numpy import random ,quantile,where
import random

# %%
x_ax = range(n)
plt.scatter(x_ax, random.sample(range(1, 500 + 1), 500))
X=random.sample(range(1, 500 + 1), 500)

# %%
model=KernelDensity()
model.fit(np.array(X).reshape(-1,1))
# Out:
# KernelDensity()

# %%
threshold
# Out:
# -6.214608128891051

# %%
scores=model.score_samples(np.array(X).reshape(-1,1))

# %%
threshold=quantile(scores,.02)

# %%
idx=where(scores<=threshold)

# %%
anominals=np.array(X).reshape(-1,1)[idx]

# %%
anominals.shape
# Out:
# (10, 1)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1, 2, 1)
plt.scatter(x_ax, random.sample(range(1, 500 + 1), 500))
plt.scatter(idx,anominals,c="r")
plt.subplot(1, 2, 2)
plt.plot(x_ax, random.sample(range(1, 500 + 1), 500))
plt.scatter(idx,anominals,c="r")

# %%
mu=1/np.sum(np.array(X).reshape(-1,1),axis=0)
var = 1 / np.array(X).shape[0] * np.sum((X - mu) ** 2, axis = 0)
